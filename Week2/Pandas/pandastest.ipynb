# %% [markdown]
# <a href="https://colab.research.google.com/github/Jyothi-Swaroop5/CodeAlpha/blob/main/Week2/Pandas/pandastest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
s=pd.Series([1,2,3,4,5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.name='numbers'
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: numbers, dtype: int64

# %%
s[1:4]
# Out:
# 1    2
# 2    3
# 3    4
# Name: numbers, dtype: int64

# %%
s.iloc[[2,3,4]]
# Out:
# 2    3
# 3    4
# 4    5
# Name: numbers, dtype: int64

# %%
s[[0,1,2]]
# Out:
# 0    1
# 1    2
# 2    3
# Name: numbers, dtype: int64

# %%
list=['a','b','c','d','e']
s.index=list
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: numbers, dtype: int64

# %%
s.loc['c']
# Out:
# np.int64(3)

# %%
s.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
d={'a':1,'b':2,'c':3}
d
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
ss=pd.Series(d)
ss
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ss.name='n'

# %%
print(ss>2)
# Out:
# a    False
# b    False
# c     True
# Name: n, dtype: bool

# %%
print(ss[(s>0.5) & (s<2)])
# Out:
# a    1
# Name: n, dtype: int64

# %%
ss['b']=33
ss
# Out:
# a     1
# b    33
# c     3
# Name: n, dtype: int64

# %%
import numpy as np
ser=pd.Series(['a',np.nan,1,np.nan,6])
ser.notnull().sum()
# Out:
# np.int64(3)

# %%
data={
    "name":['a','b','c','d','e'],
    "age":[1,2,3,np.nan,5],
    "Dep":['ds','ai','aiml',np.nan,'ece'],
    "sal":[2354,456,234,456,234]
}
data
# Out:
# {'name': ['a', 'b', 'c', 'd', 'e'],
#  'age': [1, 2, 3, nan, 5],
#  'Dep': ['ds', 'ai', 'aiml', nan, 'ece'],
#  'sal': [2354, 456, 234, 456, 234]}

# %%
df=pd.DataFrame(data)
df
# Out:
#   name  age   Dep   sal
# 0    a  1.0    ds  2354
# 1    b  2.0    ai   456
# 2    c  3.0  aiml   234
# 3    d  NaN   NaN   456
# 4    e  5.0   ece   234

# %%
df.head(2)
# Out:
#   name  age Dep   sal
# 0    a  1.0  ds  2354
# 1    b  2.0  ai   456

# %%
df.tail()
# Out:
#   name  age   Dep   sal
# 0    a  1.0    ds  2354
# 1    b  2.0    ai   456
# 2    c  3.0  aiml   234
# 3    d  NaN   NaN   456
# 4    e  5.0   ece   234

# %%
df.loc[1:3,['age','sal']]
# Out:
#    age  sal
# 1  2.0  456
# 2  3.0  234
# 3  NaN  456

# %%
df.shape
# Out:
# (5, 4)

# %%
print(df.shape)
# Out:
# (5, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   age     4 non-null      float64
#  2   Dep     4 non-null      object
#  3   sal     5 non-null      int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes

# %%
df.describe()
# Out:
#             age          sal
# count  4.000000     5.000000
# mean   2.750000   746.800000
# std    1.707825   905.282939
# min    1.000000   234.000000
# 25%    1.750000   234.000000
# 50%    2.500000   456.000000
# 75%    3.500000   456.000000
# max    5.000000  2354.000000

# %%
df['sal']=df['sal']+2000
df['sal']
# Out:
# 0    4354
# 1    2456
# 2    2234
# 3    2456
# 4    2234
# Name: sal, dtype: int64

# %%
print(df.rename(columns={'Dep':'dept'},inplace=True))
# Out:
# None

# %%
df
# Out:
#   name  age  dept   sal
# 0    a  1.0    ds  4354
# 1    b  2.0    ai  2456
# 2    c  3.0  aiml  2234
# 3    d  NaN   NaN  2456
# 4    e  5.0   ece  2234

# %%
df['psal']=df['sal']+333
df
# Out:
#   name  age  dept   sal  psal
# 0    a  1.0    ds  4354  4687
# 1    b  2.0    ai  2456  2789
# 2    c  3.0  aiml  2234  2567
# 3    d  NaN   NaN  2456  2789
# 4    e  5.0   ece  2234  2567

# %%
df.isnull().sum()
# Out:
# name    0
# age     1
# dept    1
# sal     0
# psal    0
# dtype: int64

# %%
df
# Out:
#   name  age  dept   sal  psal
# 0    a  1.0    ds  4354  4687
# 1    b  2.0    ai  2456  2789
# 2    c  3.0  aiml  2234  2567
# 3    d  NaN   NaN  2456  2789
# 4    e  5.0   ece  2234  2567

# %%
df.dropna(how='all')
# Out:
#   name  age  dept   sal  psal
# 0    a  1.0    ds  4354  4687
# 1    b  2.0    ai  2456  2789
# 2    c  3.0  aiml  2234  2567
# 3    d  NaN   NaN  2456  2789
# 4    e  5.0   ece  2234  2567

# %%
df.fillna(0)
# Out:
#   name  age  dept   sal  psal
# 0    a  1.0    ds  4354  4687
# 1    b  2.0    ai  2456  2789
# 2    c  3.0  aiml  2234  2567
# 3    d  0.0     0  2456  2789
# 4    e  5.0   ece  2234  2567

# %%
df['age'].fillna(df['age'].mean())
# Out:
# 0    1.00
# 1    2.00
# 2    3.00
# 3    2.75
# 4    5.00
# Name: age, dtype: float64

# %%
df
# Out:
#   name  age  dept   sal  psal
# 0    a  1.0    ds  4354  4687
# 1    b  2.0    ai  2456  2789
# 2    c  3.0  aiml  2234  2567
# 3    d  NaN   NaN  2456  2789
# 4    e  5.0   ece  2234  2567

# %%
df.drop(columns=5,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_7355/1914191771.py in <cell line: 0>()
# ----> 1 df.drop(columns=5,inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df

# %%
df.drop(6,inplace=True)
df

# %%
df.loc[len(df)]=['f',np.nan,'cse',3454,4564]

# %%
df

# %%
df['age'].fillna(method='bfill')

# %%
df

# %%
df['name'].replace('c','cc')

# %%
df

# %%
df['name']=df['name'].replace('c','f')

# %%
df

# %%
df.loc[6]=['a',1,'ds',4354,4687]

# %%
df

# %%
df[df.duplicated()]

# %%
df.drop_duplicates()

# %%
df['psal']=df['psal'].apply(lambda x:x/10 if x> 3455 else x )

# %%
df

# %%
df=df.drop_duplicates()

# %%
df

# %%
df['age']=df['age'].fillna(df['age'].mean())

# %%
df

# %%
df['name']=df['name'].replace('c_f','c_f_e')

# %%
df

# %%
df[['first_name','last_name']]=df['name'].str.split('_',n=1, expand=True)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7355/3274771584.py in <cell line: 0>()
# ----> 1 df[['first_name','last_name']]=df['name'].str.split('_',n=1, expand=True)
#       2 df
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
#    4301             self._set_item_frame_value(key, value)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    4339
#    4340             if isinstance(value, DataFrame):
# -> 4341                 check_key_length(self.columns, key, value)
# ...

# %%
df
# Out:
#   name  age  dept   sal  psal
# 0    a  1.0    ds  4354  4687
# 1    b  2.0    ai  2456  2789
# 2    c  3.0  aiml  2234  2567
# 3    d  NaN   NaN  2456  2789
# 4    e  5.0   ece  2234  2567

# %%
df['age']=df['age'].fillna(df['age'].median())

# %%
df
# Out:
#   name  age  dept   sal  psal
# 0    a  1.0    ds  4354  4687
# 1    b  2.0    ai  2456  2789
# 2    c  3.0  aiml  2234  2567
# 3    d  2.5   NaN  2456  2789
# 4    e  5.0   ece  2234  2567

# %%
df['age']=df['age'].apply(lambda x:x*10)

# %%
df
# Out:
#   name   age  dept   sal  psal
# 0    a  10.0    ds  4354  4687
# 1    b  20.0    ai  2456  2789
# 2    c  30.0  aiml  2234  2567
# 3    d  25.0   NaN  2456  2789
# 4    e  50.0   ece  2234  2567

# %%
import pandas as pd

# DataFrame 1
df1 = pd.DataFrame({
    'emp_id': [101, 102, 103, 104],
    'name': ['Ram', 'Sam', 'John', 'David'],
    'dept_id': [1, 2, 1, 3]
})

# DataFrame 2
df2 = pd.DataFrame({
    'dept_id': [1, 2, 3, 4],
    'department': ['HR', 'IT', 'Finance', 'Marketing']
})

print(df1)
print()
print(df2)
pd.concat([df1,df2])
pd.concat([df1,df2],axis=1)
pd.merge(df1,df2,on='dept_id')
